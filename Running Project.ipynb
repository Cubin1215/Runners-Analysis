# %%
#https://www.kaggle.com/datasets/aiaiaidavid/the-big-dataset-of-ultra-marathon-running

# %%
#Importing libraries

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES")
# Out:
# C:\Users\azadp\AppData\Local\Temp\ipykernel_7388\3078229781.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES")

# %%
#see the data head of 10

# %%
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# 1                         22           5:15:45 h   Roberto Echeverría
# 2                         22           5:16:44 h    Puro Trail Osorno
# 3                         22           5:34:13 h             Columbia
# 4                         22           5:54:14 h       Baguales Trail
# 5                         22           6:25:01 h                  NaN
# 6                         22           6:28:00 h        Los Patagones
# 7                         22           6:32:24 h       Reaktiva Chile
# 8                         22           6:39:08 h    Puro Trail Osorno
# 9                         22           6:45:11 h  Marlene Flores Team
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# 0             CHI                 1978.0              M                  M35
# 1             CHI                 1981.0              M                  M35
# 2             CHI                 1987.0              M                  M23
# 3             ARG                 1976.0              M                  M40
# 4             CHI                 1992.0              M                  M23
# 5             ARG                 1974.0              M                  M40
# 6             ARG                 1979.0              F                  W35
# 7             CHI                 1967.0              F                  W50
# 8             CHI                 1985.0              M                  M23
# 9             CHI                 1976.0              M                  M40
#
#   Athlete average speed  Athlete ID
# 0                10.286           0
# 1                 9.501           1
# 2                 9.472           2
# 3                 8.976           3
# 4                 8.469           4
# 5                 7.792           5
# 6                 7.732           6
# 7                 7.645           7
# 8                 7.516           8
# 9                 7.404           9

# %%
#To check the Shape (Rows and Columns)

# %%
df.shape
# Out:
# (7117634, 13)

# %%
#To check the type of data our dataframe has

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
#Cleaning the data

# %%
#Athlete of USA of 50km or 50mi in 2020

# %%
df[(df["Athlete country"].isin(["USA"])) & (df["Event distance/length"].isin(["50km", "50mi"])) & (df["Year of event"] == 2020)]
# Out:
#          Year of event     Event dates  \
# 2538588           2020  07.-09.02.2020
# 2538628           2020  07.-09.02.2020
# 2538860           2020      07.02.2020
# 2538883           2020      07.02.2020
# 2539317           2020      02.02.2020
# ...                ...             ...
# 2760957           2020      03.10.2020
# 2760958           2020      03.10.2020
# 2760959           2020      03.10.2020
# 2760960           2020      03.10.2020
# 2760961           2020      03.10.2020
#
#                                            Event name Event distance/length  \
# 2538588       Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538628       Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538860      Dead Sea Marathon Ein Bokek - 50km (ISR)                  50km
# 2538883      Dead Sea Marathon Ein Bokek - 50km (ISR)                  50km
# 2539317                  Gumi Dorissa Trail Run (KOR)                  50km
# ...                                               ...                   ...
# 2760957  Yankee Springs Fall Trail Run Festival (USA)                  50km
# 2760958  Yankee Springs Fall Trail Run Festival (USA)                  50km
# 2760959  Yankee Springs Fall Trail Run Festival (USA)                  50km
# 2760960  Yankee Springs Fall Trail Run Festival (USA)                  50km
# 2760961  Yankee Springs Fall Trail Run Festival (USA)                  50km
#
#          Event number of finishers Athlete performance        Athlete club  \
# 2538588                         38          10:32:38 h                 NaN
# 2538628                         38           6:09:08 h                 NaN
# 2538860                        179           5:12:29 h                 NaN
# 2538883                        179           5:33:17 h         JIM Ridolfo
# 2539317                         14           7:19:11 h                 NaN
# ...                            ...                 ...                 ...
# 2760957                         30           7:07:48 h   *East Lansing, MI
# 2760958                         30           7:27:22 h  *Traverse City, MI
# 2760959                         30           7:27:24 h  *Traverse City, MI
# 2760960                         30           7:38:30 h          *Mason, MI
# 2760961                         30           7:59:53 h                 NaN
#
#         Athlete country  Athlete year of birth Athlete gender  \
# 2538588             USA                 1975.0              M
# 2538628             USA                 1975.0              M
# 2538860             USA                 1963.0              M
# 2538883             USA                 1980.0              M
# 2539317             USA                 1971.0              M
# ...                 ...                    ...            ...
# 2760957             USA                 1958.0              F
# 2760958             USA                 1977.0              F
# 2760959             USA                 1962.0              F
# 2760960             USA                 1981.0              F
# 2760961             USA                 1980.0              M
#
#         Athlete age category Athlete average speed  Athlete ID
# 2538588                  M45                 7.632        4543
# 2538628                  M45                 8.127        4543
# 2538860                  M55                 9.601       71520
# 2538883                  M35                 9.001      366634
# 2539317                  M45                 6.831      810218
# ...                      ...                   ...         ...
# 2760957                  W60                 7.013      816361
# 2760958                  W40                 6.706      326469
# 2760959                  W55                 6.705      372174
# 2760960                  W35                 6.543      860349
# 2760961                  M35                 6.252      770097
#
# [26326 rows x 13 columns]

# %%
#Race in USA of 50km or 50mi in 2018

# %%
df2 = df[(df["Event distance/length"].isin(["50km", "50mi"])) & (df["Year of event"] == 2018) & (df["Event name"].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA')]

# %%
df2.head(10)
# Out:
#     Year of event Event dates                                     Event name  \
# 55           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 56           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 57           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 58           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 59           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 60           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 61           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 62           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 63           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 64           2018  06.01.2018    Yankee Springs 50 km Winter Challenge (USA)
#
#    Event distance/length  Event number of finishers Athlete performance  \
# 55                  50mi                          9           9:53:05 h
# 56                  50mi                          9          11:09:35 h
# 57                  50mi                          9          11:33:00 h
# 58                  50mi                          9          11:38:17 h
# 59                  50mi                          9          11:56:35 h
# 60                  50mi                          9          12:32:16 h
# 61                  50mi                          9          12:39:36 h
# 62                  50mi                          9          12:39:36 h
# 63                  50mi                          9          13:24:05 h
# 64                  50km                         36           5:09:40 h
#
#          Athlete club Athlete country  Athlete year of birth Athlete gender  \
# 55   *Middleville, MI             USA                 1983.0              M
# 56      *Waterloo, ON             CAN                 1977.0              F
# 57     *Kitchener, ON             CAN                 1976.0              M
# 58         *Utica, MI             USA                 1986.0              M
# 59    *Grass Lake, MI             USA                 1988.0              M
# 60        *Olaton, KY             USA                 1995.0              M
# 61       *Wyoming, MI             USA                 1979.0              M
# 62  *Grand Rapids, MI             USA                 1977.0              F
# 63       *Lansing, MI             USA                 1990.0              F
# 64        *Okemos, MI             USA                 1991.0              F
#
#    Athlete age category Athlete average speed  Athlete ID
# 55                  M23                 8.141          55
# 56                  W40                 7.211          56
# 57                  M40                 6.967          57
# 58                  M23                 6.914          58
# 59                  M23                 6.738          59
# 60                 MU23                 6.418          60
# 61                  M35                 6.356          61
# 62                  W40                 6.356          62
# 63                  W23                 6.004          63
# 64                  W23                 9.688          64

# %%
df2.shape
# Out:
# (64299, 13)

# %%
#Remove USA from event name

# %%
df2["Event name"] = df2["Event name"].str.split('(').str.get(0)
# Out:
# C:\Users\azadp\AppData\Local\Temp\ipykernel_7388\9866251.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Event name"] = df2["Event name"].str.split('(').str.get(0)

# %%
df2.head(10)
# Out:
#     Year of event Event dates                                Event name  \
# 55           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 56           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 57           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 58           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 59           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 60           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 61           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 62           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 63           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 64           2018  06.01.2018    Yankee Springs 50 km Winter Challenge
#
#    Event distance/length  Event number of finishers Athlete performance  \
# 55                  50mi                          9           9:53:05 h
# 56                  50mi                          9          11:09:35 h
# 57                  50mi                          9          11:33:00 h
# 58                  50mi                          9          11:38:17 h
# 59                  50mi                          9          11:56:35 h
# 60                  50mi                          9          12:32:16 h
# 61                  50mi                          9          12:39:36 h
# 62                  50mi                          9          12:39:36 h
# 63                  50mi                          9          13:24:05 h
# 64                  50km                         36           5:09:40 h
#
#          Athlete club Athlete country  Athlete year of birth Athlete gender  \
# 55   *Middleville, MI             USA                 1983.0              M
# 56      *Waterloo, ON             CAN                 1977.0              F
# 57     *Kitchener, ON             CAN                 1976.0              M
# 58         *Utica, MI             USA                 1986.0              M
# 59    *Grass Lake, MI             USA                 1988.0              M
# 60        *Olaton, KY             USA                 1995.0              M
# 61       *Wyoming, MI             USA                 1979.0              M
# 62  *Grand Rapids, MI             USA                 1977.0              F
# 63       *Lansing, MI             USA                 1990.0              F
# 64        *Okemos, MI             USA                 1991.0              F
#
#    Athlete age category Athlete average speed  Athlete ID
# 55                  M23                 8.141          55
# 56                  W40                 7.211          56
# 57                  M40                 6.967          57
# 58                  M23                 6.914          58
# 59                  M23                 6.738          59
# 60                 MU23                 6.418          60
# 61                  M35                 6.356          61
# 62                  W40                 6.356          62
# 63                  W23                 6.004          63
# 64                  W23                 9.688          64

# %%
#Make a column for athlete's age at the time of race

# %%
df2["Athlete age"] = 2018 - df2["Athlete year of birth"]
# Out:
# C:\Users\azadp\AppData\Local\Temp\ipykernel_7388\314522473.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Athlete age"] = 2018 - df2["Athlete year of birth"]

# %%
df2["Athlete age"].head()
# Out:
# 55    35.0
# 56    41.0
# 57    42.0
# 58    32.0
# 59    30.0
# Name: Athlete age, dtype: float64

# %%
#Remove h from athlete's performance

# %%
df2["Athlete performance"] = df2["Athlete performance"].str.split(" ").str.get(0)
df2["Athlete performance"].head()
# Out:
# C:\Users\azadp\AppData\Local\Temp\ipykernel_7388\887016247.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Athlete performance"] = df2["Athlete performance"].str.split(" ").str.get(0)
# 55     9:53:05
# 56    11:09:35
# 57    11:33:00
# 58    11:38:17
# 59    11:56:35
# Name: Athlete performance, dtype: object

# %%
#drop columns Athlete club, Athlete country, Athlete year of birth, Athlete age category

# %%
df2 = df2.drop(["Athlete club","Athlete country","Athlete year of birth","Athlete age category"], axis = 1)

# %%
#Clean up null values

# %%
df2.isna().sum()
# Out:
# Year of event                  0
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete gender                 0
# Athlete average speed          0
# Athlete ID                     0
# Athlete age                  575
# dtype: int64

# %%
df2[df2["Athlete age"].isna()==1]
# Out:
#         Year of event Event dates                       Event name  \
# 453              2018  01.01.2018                    Red Eye 50km
# 456              2018  01.01.2018                    Red Eye 50km
# 459              2018  01.01.2018                    Red Eye 50km
# 460              2018  01.01.2018                    Red Eye 50km
# 13214            2018  17.03.2018  Lt. JC Stone 50K UltraMarathon
# ...               ...         ...                              ...
# 659684           2018  27.10.2018      Lake Hodges Trail Fest 50K
# 659685           2018  27.10.2018      Lake Hodges Trail Fest 50K
# 659688           2018  27.10.2018      Lake Hodges Trail Fest 50K
# 659689           2018  27.10.2018      Lake Hodges Trail Fest 50K
# 659690           2018  27.10.2018      Lake Hodges Trail Fest 50K
#
#        Event distance/length  Event number of finishers Athlete performance  \
# 453                     50km                         21             5:10:00
# 456                     50km                         21             5:44:00
# 459                     50km                         21             6:07:00
# 460                     50km                         21             6:12:00
# 13214                   50km                         34             4:54:43
# ...                      ...                        ...                 ...
# 659684                  50km                        133             8:24:14
# 659685                  50km                        133             8:25:12
# 659688                  50km                        133             8:29:59
# 659689                  50km                        133             8:31:30
# 659690                  50km                        133             8:35:28
#
#        Athlete gender Athlete average speed  Athlete ID  Athlete age
# 453                 M                 9.677         453          NaN
# 456                 M                 8.721         456          NaN
# 459                 M                 8.174         459          NaN
# 460                 M                 8.065         460          NaN
# 13214               F                10.179       12483          NaN
# ...               ...                   ...         ...          ...
# 659684              F                  5.95      374269          NaN
# 659685              F                 5.938      358717          NaN
# 659688              M                 5.883      204804          NaN
# 659689              F                 5.865      374272          NaN
# 659690              M                  5.82      374273          NaN
#
# [575 rows x 10 columns]

# %%
df2 = df2.dropna()

# %%
df2.shape
# Out:
# (63724, 10)

# %%
#Check for duplicates

# %%
df2[df2.duplicated()== True]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, Athlete age]
# Index: []

# %%
#reset index

# %%
df2.reset_index(drop = True)
# Out:
#        Year of event     Event dates  \
# 0               2018      06.01.2018
# 1               2018      06.01.2018
# 2               2018      06.01.2018
# 3               2018      06.01.2018
# 4               2018      06.01.2018
# ...              ...             ...
# 63719           2018  27.-28.10.2018
# 63720           2018  27.-28.10.2018
# 63721           2018  27.-28.10.2018
# 63722           2018  27.-28.10.2018
# 63723           2018  27.-28.10.2018
#
#                                      Event name Event distance/length  \
# 0      Yankee Springs 50 Mile Winter Challenge                   50mi
# 1      Yankee Springs 50 Mile Winter Challenge                   50mi
# 2      Yankee Springs 50 Mile Winter Challenge                   50mi
# 3      Yankee Springs 50 Mile Winter Challenge                   50mi
# 4      Yankee Springs 50 Mile Winter Challenge                   50mi
# ...                                         ...                   ...
# 63719                      Cactus Rose 50 Mile                   50mi
# 63720                      Cactus Rose 50 Mile                   50mi
# 63721                      Cactus Rose 50 Mile                   50mi
# 63722                      Cactus Rose 50 Mile                   50mi
# 63723                      Cactus Rose 50 Mile                   50mi
#
#        Event number of finishers Athlete performance Athlete gender  \
# 0                              9             9:53:05              M
# 1                              9            11:09:35              F
# 2                              9            11:33:00              M
# 3                              9            11:38:17              M
# 4                              9            11:56:35              M
# ...                          ...                 ...            ...
# 63719                         29            17:05:58              M
# 63720                         29            18:13:01              M
# 63721                         29            18:49:58              M
# 63722                         29            23:30:00              M
# 63723                         29            25:40:10              M
#
#       Athlete average speed  Athlete ID  Athlete age
# 0                     8.141          55         35.0
# 1                     7.211          56         41.0
# 2                     6.967          57         42.0
# 3                     6.914          58         32.0
# 4                     6.738          59         30.0
# ...                     ...         ...          ...
# 63719                 4.706       68122         46.0
# 63720                 4.417       23336         65.0
# 63721                 4.273      375022         32.0
# 63722                 3.424       68273         66.0
# 63723                 3.135      341648         67.0
#
# [63724 rows x 10 columns]

# %%
#Fix types

# %%
df2["Athlete age"] = df2["Athlete age"].astype(int)

# %%
df2["Athlete average speed"] = df2["Athlete average speed"].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# Athlete age                    int32
# dtype: object

# %%
#Rename Columns

# %%
df2.columns
# Out:
# Index(['Year of event', 'Event dates', 'Event name', 'Event distance/length',
#        'Event number of finishers', 'Athlete performance', 'Athlete gender',
#        'Athlete average speed', 'Athlete ID', 'Athlete age'],
#       dtype='object')

# %%
df2 = df2.rename(columns = {'Year of event' : "year", 
                             'Event dates': "race_day", 
                             'Event name' : "event_name", 
                             'Event distance/length' : "race_length",
                             'Event number of finishers' : "number_of_finishers", 
                             'Athlete performance' : "athlete_performance", 
                             'Athlete gender' : "athlete_gender",
                             'Athlete average speed': "athlete_average_speed",
                             'Athlete ID' : "athlete_age", 
                             'Athlete age' : "athlete_age"
                           })

# %%
df2 = df2.rename(columns = {"athlete_age" : "athlete_id"})
df2.columns.values[9] = "athlete_age"

# %%
df2.head(10)
# Out:
#     year    race_day                                event_name race_length  \
# 55  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 56  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 57  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 58  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 59  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 60  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 61  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 62  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 63  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 64  2018  06.01.2018    Yankee Springs 50 km Winter Challenge         50km
#
#     number_of_finishers athlete_performance athlete_gender  \
# 55                    9             9:53:05              M
# 56                    9            11:09:35              F
# 57                    9            11:33:00              M
# 58                    9            11:38:17              M
# 59                    9            11:56:35              M
# 60                    9            12:32:16              M
# 61                    9            12:39:36              M
# 62                    9            12:39:36              F
# 63                    9            13:24:05              F
# 64                   36             5:09:40              F
#
#     athlete_average_speed  athlete_id  athlete_age
# 55                  8.141          55           35
# 56                  7.211          56           41
# 57                  6.967          57           42
# 58                  6.914          58           32
# 59                  6.738          59           30
# 60                  6.418          60           23
# 61                  6.356          61           39
# 62                  6.356          62           41
# 63                  6.004          63           28
# 64                  9.688          64           27

# %%
#reorder columns

# %%
df2.columns
# Out:
# Index(['year', 'race_day', 'event_name', 'race_length', 'number_of_finishers',
#        'athlete_performance', 'athlete_gender', 'athlete_average_speed',
#        'athlete_id', 'athlete_age'],
#       dtype='object')

# %%
df3 = df2[["race_day", 'event_name', 'race_length', 'number_of_finishers',
'athlete_id','athlete_gender', 'athlete_age','athlete_performance', 'athlete_average_speed']]

# %%
df3.head(10)
# Out:
#       race_day                                event_name race_length  \
# 55  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 56  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 57  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 58  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 59  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 60  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 61  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 62  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 63  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 64  06.01.2018    Yankee Springs 50 km Winter Challenge         50km
#
#     number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 55                    9          55              M           35
# 56                    9          56              F           41
# 57                    9          57              M           42
# 58                    9          58              M           32
# 59                    9          59              M           30
# 60                    9          60              M           23
# 61                    9          61              M           39
# 62                    9          62              F           41
# 63                    9          63              F           28
# 64                   36          64              F           27
#
#    athlete_performance  athlete_average_speed
# 55             9:53:05                  8.141
# 56            11:09:35                  7.211
# 57            11:33:00                  6.967
# 58            11:38:17                  6.914
# 59            11:56:35                  6.738
# 60            12:32:16                  6.418
# 61            12:39:36                  6.356
# 62            12:39:36                  6.356
# 63            13:24:05                  6.004
# 64             5:09:40                  9.688

# %%
#finding entries of race named Everglades 50 Mile Ultra Run

# %%
df3[df3["event_name"] == "Everglades 50 Mile Ultra Run "]
# Out:
#          race_day                     event_name race_length  \
# 51923  17.02.2018  Everglades 50 Mile Ultra Run         50mi
# 51924  17.02.2018  Everglades 50 Mile Ultra Run         50mi
# 51925  17.02.2018  Everglades 50 Mile Ultra Run         50mi
# 51926  17.02.2018  Everglades 50 Mile Ultra Run         50mi
# 51927  17.02.2018  Everglades 50 Mile Ultra Run         50mi
# 51928  17.02.2018  Everglades 50 Mile Ultra Run         50mi
# 51929  17.02.2018  Everglades 50 Mile Ultra Run         50mi
# 51930  17.02.2018  Everglades 50 Mile Ultra Run         50mi
# 51931  17.02.2018  Everglades 50 Mile Ultra Run         50mi
# 51932  17.02.2018  Everglades 50 Mile Ultra Run         50mi
# 51933  17.02.2018  Everglades 50 Mile Ultra Run         50mi
# 51934  17.02.2018  Everglades 50 Mile Ultra Run         50mi
# 51935  17.02.2018  Everglades 50 Mile Ultra Run         50mi
# 51936  17.02.2018  Everglades 50 Mile Ultra Run         50mi
# 51937  17.02.2018  Everglades 50 Mile Ultra Run         50mi
# 51938  17.02.2018  Everglades 50 Mile Ultra Run         50mi
# 51939  17.02.2018  Everglades 50 Mile Ultra Run         50mi
# 51940  17.02.2018  Everglades 50 Mile Ultra Run         50mi
# 51941  17.02.2018  Everglades 50 Mile Ultra Run         50mi
# 51942  17.02.2018  Everglades 50 Mile Ultra Run         50mi
# 51943  17.02.2018  Everglades 50 Mile Ultra Run         50mi
# 51944  17.02.2018  Everglades 50 Mile Ultra Run         50mi
# 51945  17.02.2018  Everglades 50 Mile Ultra Run         50mi
#
#        number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 51923                   23       47601              M           38
# 51924                   23       37220              M           29
# 51925                   23       47602              M           39
# 51926                   23       47603              M           51
# 51927                   23       47604              M           32
# 51928                   23       47605              M           40
# 51929                   23       36476              M           54
# 51930                   23       47606              M           49
# 51931                   23       47607              M           42
# 51932                   23       47608              M           37
# 51933                   23       47609              M           38
# 51934                   23       47610              M           35
# 51935                   23       47611              F           33
# 51936                   23       47612              F           38
# 51937                   23       47613              M           61
# 51938                   23       47614              F           51
# 51939                   23       47615              M           51
# 51940                   23       19081              M           50
# 51941                   23       47616              F           50
# 51942                   23       12531              M           40
# 51943                   23       34666              F           23
# 51944                   23       47617              F           47
# 51945                   23       47618              M           43
#
#       athlete_performance  athlete_average_speed
# 51923             7:00:00                 11.495
# 51924             8:29:48                  9.470
# 51925             8:45:31                  9.187
# 51926             9:01:52                  8.910
# 51927             9:26:06                  8.529
# 51928             9:40:18                  8.320
# 51929             9:42:43                  8.285
# 51930             9:55:37                  8.106
# 51931             9:58:07                  8.072
# 51932            10:21:15                  7.771
# 51933            10:47:05                  7.461
# 51934            10:56:06                  7.359
# 51935            10:56:50                  7.350
# 51936            11:01:52                  7.295
# 51937            11:35:50                  6.938
# 51938            11:46:45                  6.831
# 51939            12:04:12                  6.667
# 51940            12:11:39                  6.599
# 51941            12:41:05                  6.344
# 51942            12:43:43                  6.322
# 51943            13:57:09                  5.767
# 51944            13:57:10                  5.767
# 51945            13:57:10                  5.767

# %%
#finding entries with athlete_id 1100

# %%
df3[df3["athlete_id"] == 1100]
# Out:
#          race_day                                         event_name  \
# 1102   24.03.2018  XTERRA Northeast Trail Run Series – Shepaug Ru...
# 90185  05.05.2018     Endurance Challenge - New York Trail 50 Miles
#
#       race_length  number_of_finishers  athlete_id athlete_gender  \
# 1102         50km                   10        1100              M
# 90185        50mi                  271        1100              M
#
#        athlete_age athlete_performance  athlete_average_speed
# 1102            38             5:51:48                  8.528
# 90185           38            10:53:44                  7.385

# %%
#charts and graphs

# %%
df3["race_length"] = df3["race_length"].astype("category")
# Out:
# C:\Users\azadp\AppData\Local\Temp\ipykernel_7388\1862522557.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["race_length"] = df3["race_length"].astype("category")

# %%
df3.groupby(['race_length', 'athlete_gender']).count()
# Out:
# C:\Users\azadp\AppData\Local\Temp\ipykernel_7388\740476109.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df3.groupby(['race_length', 'athlete_gender']).count()
#                             race_day  event_name  number_of_finishers  \
# race_length athlete_gender
# 50km        F                  17103       17103                17103
#             M                  31065       31065                31065
#             X                      2           2                    2
# 50mi        F                   4729        4729                 4729
#             M                  10824       10824                10824
#             X                      1           1                    1
#
#                             athlete_id  athlete_age  athlete_performance  \
# race_length athlete_gender
# 50km        F                    17103        17103                17103
#             M                    31065        31065                31065
#             X                        2            2                    2
# 50mi        F                     4729         4729                 4729
#             M                    10824        10824                10824
#             X                        1            1                    1
#
#                             athlete_average_speed
# race_length athlete_gender
# 50km        F                               17103
#             M                               31065
#             X                                   2
# 50mi        F                                4729
#             M                               10824
#             X                                   1

# %%
sns.histplot(df3["race_length"])
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.histplot(df3, x = 'race_length', hue = 'athlete_gender')
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.displot(df3[df3['race_length'] == "50mi"]['athlete_average_speed'])

# %%
sns.violinplot(data=df3, x='race_length', y='athlete_average_speed', hue='athlete_gender', split=True, inner= "quart", linewidth = 1)
# Out:
# <Axes: xlabel='race_length', ylabel='athlete_average_speed'>

# %%
sns.lmplot(data=df3, x='athlete_age', y='athlete_average_speed', hue='athlete_gender')

# %%
#questions I want to find out from the data

# %%
#Difference in speed in 50km & 50mi from male to female to X

# %%
df3.groupby("athlete_gender")["athlete_average_speed"].mean()
# Out:
# athlete_gender
# F    6.959843
# M    7.569282
# X    7.628333
# Name: athlete_average_speed, dtype: float64

# %%
#What age group is the best in the 50km race (more than 20 races)

# %%
df3.query('race_length == "50km"').groupby("athlete_age")["athlete_average_speed"].agg(["mean","count"]).sort_values("mean", ascending =False).query('count>20')
# Out:
#                  mean  count
# athlete_age
# 20           8.110445    155
# 23           8.003496    379
# 27           7.989370    884
# 24           7.977480    496
# 22           7.947148    284
# ...               ...    ...
# 74           6.229061     33
# 71           6.021672     58
# 75           5.904226     31
# 73           5.796250     32
# 72           5.710216     37
#
# [61 rows x 2 columns]

# %%
#Season for the data -> Slower in summer than winter?

#Spring = 3-5
#Summer = 6-8
#Fall = 8-11
#Winter = 12-2

# %%
df3["race_month"] = df3["race_day"].str.split(".").str.get(1).astype(int)

# %%
df3.head(10)
# Out:
#       race_day                                event_name race_length  \
# 55  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 56  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 57  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 58  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 59  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 60  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 61  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 62  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 63  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 64  06.01.2018    Yankee Springs 50 km Winter Challenge         50km
#
#     number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 55                    9          55              M           35
# 56                    9          56              F           41
# 57                    9          57              M           42
# 58                    9          58              M           32
# 59                    9          59              M           30
# 60                    9          60              M           23
# 61                    9          61              M           39
# 62                    9          62              F           41
# 63                    9          63              F           28
# 64                   36          64              F           27
#
#    athlete_performance  athlete_average_speed  race_month
# 55             9:53:05                  8.141           1
# 56            11:09:35                  7.211           1
# 57            11:33:00                  6.967           1
# 58            11:38:17                  6.914           1
# 59            11:56:35                  6.738           1
# 60            12:32:16                  6.418           1
# 61            12:39:36                  6.356           1
# 62            12:39:36                  6.356           1
# 63            13:24:05                  6.004           1
# 64             5:09:40                  9.688           1

# %%
df3["race_month"] = df3["race_month"].apply(lambda x : 'Winter' if x>11 else 'Fall' if x>7 else 'Summer' if x>5 else 'Spring' if x>2 else 'Winter')

# %%
df3.head(10)
# Out:
#       race_day                                event_name race_length  \
# 55  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 56  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 57  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 58  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 59  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 60  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 61  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 62  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 63  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 64  06.01.2018    Yankee Springs 50 km Winter Challenge         50km
#
#     number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 55                    9          55              M           35
# 56                    9          56              F           41
# 57                    9          57              M           42
# 58                    9          58              M           32
# 59                    9          59              M           30
# 60                    9          60              M           23
# 61                    9          61              M           39
# 62                    9          62              F           41
# 63                    9          63              F           28
# 64                   36          64              F           27
#
#    athlete_performance  athlete_average_speed race_month
# 55             9:53:05                  8.141     Winter
# 56            11:09:35                  7.211     Winter
# 57            11:33:00                  6.967     Winter
# 58            11:38:17                  6.914     Winter
# 59            11:56:35                  6.738     Winter
# 60            12:32:16                  6.418     Winter
# 61            12:39:36                  6.356     Winter
# 62            12:39:36                  6.356     Winter
# 63            13:24:05                  6.004     Winter
# 64             5:09:40                  9.688     Winter

# %%
df3.groupby("race_month")['athlete_average_speed'].agg(['mean','count']).sort_values('mean', ascending = False)
# Out:
#                 mean  count
# race_month
# Spring      7.486591  20462
# Winter      7.431837  13409
# Fall        7.276780  20358
# Summer      7.167459   9495

# %%
#50 milers only

# %%
df3.query('race_length == "50mi"').groupby("race_month")['athlete_average_speed'].agg(['mean','count']).sort_values('mean', ascending = False)
# Out:
#                 mean  count
# race_month
# Fall        7.319862   4320
# Spring      7.312843   4836
# Summer      6.953252   3050
# Winter      6.758153   3348
